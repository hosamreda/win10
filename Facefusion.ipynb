# %% [markdown]
# <a href="https://colab.research.google.com/github/hosamreda/win10/blob/main/Facefusion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
#
# لمزيد من شروحات الذكاء الاصطناعي المجانية لا تنسى الاشتراك في قناتنا JORA TECH
#
# [**اشترك الان**
# ](https://www.youtube.com/channel/UCD7_SFXaa9tTx43aoZlxZ_w)
#
# For more AI tutorials subscribe Body Tech YouTube channel
#
# [**SUBSCRIBE NOW**](https://www.youtube.com/channel/UCD7_SFXaa9tTx43aoZlxZ_w)

# %%
# @title
from IPython.display import clear_output
import codecs
import torch

if torch.cuda.is_available():
  device="cuda"
  # !apt-get install nvidia-cuda-toolkit
  print("Using GPU")
else:
  device="cpu"
  print("Using CPU")

giturl = codecs.decode('uggcf://tvguho.pbz/Mnpulfnhef/snprshfvba.tvg','rot_13')
gitdir = codecs.decode('snprshfvba','rot_13')
# !git clone {giturl}
# %cd /content/{gitdir}
# !python install.py --onnxruntime cuda-11.8 --skip-conda

clear_output()
print("Installed!")
# Out:
# Installed!

# %%
# @title
import codecs
gitdir = codecs.decode('snprshfvba','rot_13')
# %cd /content/{gitdir}

if device=="cuda":
  # !python run.py --execution-providers cpu cuda
else:
  # !python run.py --execution-providers cpu
# Out:
# /content/facefusion
# Downloading: 100% 22.5M/22.5M [00:00<00:00, 39.2MB/s]
# Downloading: 100% 93.4M/93.4M [00:00<00:00, 102MB/s]
# Downloading: 100% 922k/922k [00:00<00:00, 2.01MB/s]
# Downloading: 100% 1.26M/1.26M [00:00<00:00, 3.65MB/s]
# Downloading: 100% 12.1M/12.1M [00:00<00:00, 25.7MB/s]
# Downloading: 100% 166M/166M [00:01<00:00, 104MB/s]
# Downloading: 100% 67.1M/67.1M [00:00<00:00, 76.6MB/s]
# Downloading: 100% 50.7M/50.7M [00:00<00:00, 90.5MB/s]
# Downloading: 100% 63.7M/63.7M [00:00<00:00, 84.4MB/s]
# Downloading: 100% 265M/265M [00:01<00:00, 139MB/s]
# IMPORTANT: You are using gradio version 3.50.2, however version 4.29.0 is available, please upgrade.
# --------
# IMPORTANT: You are using gradio version 3.50.2, however version 4.29.0 is available, please upgrade.
# --------
# IMPORTANT: You are using gradio version 3.50.2, however version 4.29.0 is available, please upgrade.
# --------
# ...
